# %% [markdown]
# # CNN --> Convolution Neural Network

# %%
# !nvidia-smi
# Out:
# Sat Sep  9 09:53:18 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8     9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# In machinelearning
# pandas
# numpy
# scikit learn
# seaborn/matplotlib
#
#
# deep learning
# tensorflow
# pytorch
# keras
#
# opencv
# nltk
# gensim
# spacy

# %%
car_image_path ='/content/car.jpeg'

# %%
car_image_path
# Out:
# '/content/car.jpeg'

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import cv2#opencv

# %%
img=cv2.imread(car_image_path)

# %%
img.shape
# Out:
# (168, 300, 3)

# %%
img
# Out:
# array([[[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        [[237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237],
#         ...,
#         [237, 237, 237],
#         [237, 237, 237],
#         [237, 237, 237]],
#
#        ...,
#
#        [[216, 216, 216],
#         [216, 216, 216],
#         [216, 216, 216],
#         ...,
#         [211, 211, 211],
#         [211, 211, 211],
#         [211, 211, 211]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
#         ...,
#         [213, 213, 213],
#         [213, 213, 213],
#         [213, 213, 213]],
#
#        [[217, 217, 217],
#         [217, 217, 217],
#         [217, 217, 217],
#         ...,
#         [214, 214, 214],
#         [214, 214, 214],
#         [214, 214, 214]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
# color img have 3 channel Red blue and green
# RGB get convert after plt.imshow(img) reverse the order of color like BGR that why the look like blue color

# %%
img2=cv2.cvtColor(img,cv2. COLOR_BGR2RGB)

# %%
img2.shape
# Out:
# (168, 300, 3)

# %%
plt.imshow(img2)

# %%
img3=cv2.cvtColor(img,cv2. COLOR_BGR2GRAY)

# %%
img3.shape
# Out:
# (168, 300)

# %%
plt.imshow(img3)

# %%
plt.imshow(img3 , cmap ="gray")

# %%
#this is also provide the image
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
img3.shape
# Out:
# (168, 300)

# %%
row,col = img3.shape

# %%
car = img3.reshape(1,row,col,1)

# %%
car.shape
# Out:
# (1, 168, 300, 1)

# %%
con_layer = [tf.keras.layers.Conv2D(
    filters= 1,
    kernel_size = (3,3),
    strides = (1,1),
    input_shape=car.shape[1:]
    )]

# %%
conv_model =tf.keras.Sequential(con_layer)

# %%
conv_model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_6 (Conv2D)           (None, 166, 298, 1)       10
#
# =================================================================
# Total params: 10 (40.00 Byte)
# Trainable params: 10 (40.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# batch mark data mnist,

# %%
output =conv_model.predict(car)
# Out:
# 1/1 [==============================] - 0s 17ms/step

# %%
# we need to make 4d go to the data and make 4d car = img3.reshape(1,row,col,1)

# %%
output.shape
# Out:
# (1, 166, 298, 1)

# %%
((168 + 0 - 3)//1)+1
# Out:
# 166

# %%
row,col =output.shape[1:-1]

# %%
reshape_output = output.reshape(row,col)

# %%
plt.imshow(reshape_output,cmap="gray")

# %%
img2.shape
# Out:
# (168, 300, 3)

# %%
color_car = img2

# %%
row,col,depth =img2.shape

# %%
color_car.reshape(1,row,col,depth)
# Out:
# array([[[[237, 237, 237],
#          [237, 237, 237],
#          [237, 237, 237],
#          ...,
#          [237, 237, 237],
#          [237, 237, 237],
#          [237, 237, 237]],
#
#         [[237, 237, 237],
#          [237, 237, 237],
#          [237, 237, 237],
#          ...,
#          [237, 237, 237],
#          [237, 237, 237],
#          [237, 237, 237]],
#
#         [[237, 237, 237],
#          [237, 237, 237],
#          [237, 237, 237],
#          ...,
#          [237, 237, 237],
#          [237, 237, 237],
#          [237, 237, 237]],
#
#         ...,
#
#         [[216, 216, 216],
#          [216, 216, 216],
#          [216, 216, 216],
#          ...,
#          [211, 211, 211],
#          [211, 211, 211],
#          [211, 211, 211]],
#
#         [[217, 217, 217],
#          [217, 217, 217],
#          [217, 217, 217],
#          ...,
#          [213, 213, 213],
#          [213, 213, 213],
#          [213, 213, 213]],
#
#         [[217, 217, 217],
#          [217, 217, 217],
#          [217, 217, 217],
#          ...,
#          [214, 214, 214],
#          [214, 214, 214],
#          [214, 214, 214]]]], dtype=uint8)

# %%
reshape_color_img=color_car.reshape(1,row,col,depth)

# %%
 reshape_color_img.shape[1:]
# Out:
# (168, 300, 3)

# %%
conv_layer =[tf.keras.layers.Conv2D(
    filters = 1,
    kernel_size = (3,3),
    strides =(1,1),
    input_shape = reshape_color_img.shape[1:]
)]

# %%
conv_model =tf.keras.Sequential(conv_layer)

# %%
conv_model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 166, 298, 1)       28
#
# =================================================================
# Total params: 28 (112.00 Byte)
# Trainable params: 28 (112.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
color_output =conv_model.predict(reshape_color_img)
# Out:
# 1/1 [==============================] - 0s 235ms/step

# %%
color_output.shape
# Out:
# (1, 166, 298, 1)

# %%
row,col =color_output.shape[1:-1]

# %%
reshape_output = color_output.reshape(row,col)

# %%
plt.imshow(reshape_output)

# %%
plt.imshow(reshape_output,cmap = "gray")

# %%
color_car.shape
# Out:
# (168, 300, 3)

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=300x168>

# %%
def reshaping_in(img, grayscale=True):
  if grayscale:
    row,col = img.shape
    img = img.reshape(1,row,col,1) # grayscale
    return img
  row,col,depth = img.shape
  color_img = img.reshape(1,row,col,depth) # colored
  return color_img

# %%
def max_pooling(img, pool_size=(2,2), strides=(2,2)):
  reshaped_img = reshaping_in(img,grayscale=False)
  pooling_layer = tf.keras.layers.MaxPool2D(pool_size=pool_size, strides=strides)
  result = pooling_layer(reshaped_img)
  return result

# %%
result=max_pooling(color_car)

# %%
result.shape
# Out:
# TensorShape([1, 84, 150, 3])

# %%
def plot(result):
  _,row,col,_=result.shape
  reshaped_img=tf.reshape(result,(row,col,3))
  plt.imshow(reshaped_img)

# %%
plot(result)

# %%
# do for min ,avg and global also
def max_pooling(img, pool_size=(2,2), strides=(2,2)):
  reshaped_img = reshaping_in(img,grayscale=False)
  pooling_layer = tf.keras.layers.MaxPool2D(pool_size=pool_size, strides=strides)
  result = pooling_layer(reshaped_img)
  return result

# %%
def reshaping_in(img, grayscale=True):
  if grayscale:
    row,col = img.shape
    img = img.reshape(1,row,col,1) # grayscale
    return img
  row,col,depth = img.shape
  color_img = img.reshape(1,row,col,depth) # colored
  return color_img

# %%
def get_conv_model(filters=1, filter_size=(3,3), strides=(1,1), input_shape=None, padding="valid"):
  CONV_LAYER = [tf.keras.layers.Conv2D(filters=filters,
                                      kernel_size=filter_size,
                                      strides=(1,1),
                                      input_shape=input_shape,
                                      padding=padding)]

  conv_model = tf.keras.Sequential(CONV_LAYER)
  conv_model.summary()
  return conv_model

# %%
def apply_conv_model_and_visualize(img, conv_model):
  try:
    out = conv_model.predict(img)
    print(out.shape)
    row, col, depth = out.shape[1:]
    reshape_out = out.reshape(row, col, depth)

    for d in range(depth):
      plt.imshow(reshape_out[:,:,d], cmap="gray")
      plt.show()

  except Exception as e:
    raise e

# %%
input_img = reshaping_in(color_car,grayscale =False)
model =get_conv_model(filters =10,filter_size =(3,3),strides=(1,1),input_shape =input_img.shape[1:])
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_10 (Conv2D)          (None, 166, 298, 10)      280
#
# =================================================================
# Total params: 280 (1.09 KB)
# Trainable params: 280 (1.09 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
apply_conv_model_and_visualize(input_img,model)
# Out:
# 1/1 [==============================] - 0s 73ms/step
# (1, 166, 298, 10)
